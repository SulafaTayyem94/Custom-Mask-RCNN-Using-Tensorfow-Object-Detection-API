# %% [markdown]
# #Environment Setup

# %%
# downgrade tensorflow version
print('python version')
# !python --version
print('current tf version')
# !python -c 'import tensorflow as tf; print(tf.__version__)'
# !pip uninstall tensorflow==2.2
# !pip install tensorflow-gpu==1.13.0
print('new tf version')
# !python -c 'import tensorflow as tf; print(tf.__version__)'

# %%
# !apt-get install protobuf-compiler python-pil python-lxml python-tk
# !pip install Cython
# !pip install jupyter
# !pip install matplotlib
# !pip install tf_slim

# !git clone https://github.com/tensorflow/models.git

# %cd /content/models/research

# !protoc object_detection/protos/*.proto --python_out=.

# %set_env PYTHONPATH=/content/models/research:/content/models/research/slim

# !python object_detection/builders/model_builder_test.py
# Out:
# /bin/sh: apt-get: command not found
# Collecting Cython
#   Downloading https://files.pythonhosted.org/packages/5b/20/14340be316bb54a3de761448fa5bc9cee951baef18b409b1186d2a1ed1fc/Cython-0.29.19-cp37-cp37m-macosx_10_9_x86_64.whl (1.9MB)
#      |████████████████████████████████| 1.9MB 3.4MB/s
# Installing collected packages: Cython
# ^C
# ERROR: Operation cancelled by user
# Requirement already satisfied: jupyter in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (1.0.0)
# Requirement already satisfied: ipywidgets in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from jupyter) (7.5.1)
# Requirement already satisfied: qtconsole in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from jupyter) (4.7.2)
# Requirement already satisfied: jupyter-console in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from jupyter) (6.1.0)
# Requirement already satisfied: ipykernel in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from jupyter) (5.1.4)
# Requirement already satisfied: notebook in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from jupyter) (6.0.3)
# Requirement already satisfied: nbconvert in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from jupyter) (5.6.1)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from ipywidgets->jupyter) (7.13.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from ipywidgets->jupyter) (3.5.1)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from ipywidgets->jupyter) (4.3.3)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from ipywidgets->jupyter) (5.0.4)
# Requirement already satisfied: jupyter-core in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from qtconsole->jupyter) (4.6.1)
# Requirement already satisfied: qtpy in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from qtconsole->jupyter) (1.9.0)
# Requirement already satisfied: pyzmq>=17.1 in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from qtconsole->jupyter) (18.1.1)
# Requirement already satisfied: ipython-genutils in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from qtconsole->jupyter) (0.2.0)
# Requirement already satisfied: jupyter-client>=4.1 in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from qtconsole->jupyter) (6.1.0)
# Requirement already satisfied: pygments in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from qtconsole->jupyter) (2.6.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from jupyter-console->jupyter) (3.0.4)
# Requirement already satisfied: tornado>=4.2 in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from ipykernel->jupyter) (6.0.4)
# Requirement already satisfied: appnope; platform_system == "Darwin" in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from ipykernel->jupyter) (0.1.0)
# Requirement already satisfied: jinja2 in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from notebook->jupyter) (2.11.1)
# Requirement already satisfied: terminado>=0.8.1 in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from notebook->jupyter) (0.8.3)
# Requirement already satisfied: prometheus-client in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from notebook->jupyter) (0.7.1)
# Requirement already satisfied: Send2Trash in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from notebook->jupyter) (1.5.0)
# Requirement already satisfied: bleach in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from nbconvert->jupyter) (3.1.0)
# Requirement already satisfied: testpath in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from nbconvert->jupyter) (0.4.4)
# Requirement already satisfied: defusedxml in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from nbconvert->jupyter) (0.6.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from nbconvert->jupyter) (1.4.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from nbconvert->jupyter) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from nbconvert->jupyter) (0.3)
# Requirement already satisfied: jedi>=0.10 in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter) (0.16.0)
# Requirement already satisfied: decorator in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter) (4.4.2)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter) (4.8.0)
# Requirement already satisfied: pickleshare in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter) (0.7.5)
# Requirement already satisfied: backcall in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter) (0.1.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter) (41.4.0)
# Requirement already satisfied: six in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from traitlets>=4.3.1->ipywidgets->jupyter) (1.12.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets->jupyter) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from jupyter-client>=4.1->qtconsole->jupyter) (2.8.1)
# Requirement already satisfied: wcwidth in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter) (0.1.8)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from jinja2->notebook->jupyter) (1.1.1)
# Requirement already satisfied: webencodings in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from bleach->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: parso>=0.5.2 in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter) (0.6.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter) (0.6.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter) (19.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter) (1.5.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter) (0.15.7)
# Requirement already satisfied: zipp>=0.5 in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter) (2.2.0)
# Collecting matplotlib
#   Downloading https://files.pythonhosted.org/packages/0d/61/b741990b429341bac1af5f5c645ee7aaa3bbe7daf3418d283c92c4b5ee82/matplotlib-3.2.1-cp37-cp37m-macosx_10_9_x86_64.whl (12.4MB)
#      |████████████████████████████████| 12.5MB 2.1MB/s
# Collecting kiwisolver>=1.0.1
#   Downloading https://files.pythonhosted.org/packages/81/c5/9831f281c6fb57945e83fdf39ff036cacfdc84aa1988bb3150b330533050/kiwisolver-1.2.0-cp37-cp37m-macosx_10_9_x86_64.whl (60kB)
#      |████████████████████████████████| 61kB 10.9MB/s
# Requirement already satisfied: python-dateutil>=2.1 in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from matplotlib) (2.8.1)
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1
#   Downloading https://files.pythonhosted.org/packages/8a/bb/488841f56197b13700afd5658fc279a2025a39e22449b7cf29864669b15d/pyparsing-2.4.7-py2.py3-none-any.whl (67kB)
#      |████████████████████████████████| 71kB 3.2MB/s
# Collecting cycler>=0.10
#   Downloading https://files.pythonhosted.org/packages/f7/d2/e07d3ebb2bd7af696440ce7e754c59dd546ffe1bbe732c8ab68b9c834e61/cycler-0.10.0-py2.py3-none-any.whl
# Requirement already satisfied: numpy>=1.11 in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from matplotlib) (1.18.1)
# Requirement already satisfied: six>=1.5 in /Users/vijendra1125/miniconda3/lib/python3.7/site-packages (from python-dateutil>=2.1->matplotlib) (1.12.0)
# Installing collected packages: kiwisolver, pyparsing, cycler, matplotlib
# Successfully installed cycler-0.10.0 kiwisolver-1.2.0 matplotlib-3.2.1 pyparsing-2.4.7
# Cloning into 'models'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (31/31), done.
# Receiving objects:  99% (36092/36456), 512.15 MiB | 4.92 MiB/sReceiving objects:  99% (36415/36456), 519.52 MiB | 4.78 MiB/sremote: Total 36456 (delta 8), reused 27 (delta 2), pack-reused 36423
# Receiving objects: 100% (36456/36456), 520.20 MiB | 4.89 MiB/s, done.
# Resolving deltas: 100% (24294/24294), done.
# Checking out files: 100% (2550/2550), done.
# [Errno 2] No such file or directory: '/content/models/research'
# /Users/vijendra1125/Documents/CV/my_repos/Custom-Mask-RCNN-using-Tensorfow-Object-detection-API
# object_detection/protos/*.proto: No such file or directory
# env: PYTHONPATH=/content/models/research:/content/models/research/slim
# python: can't open file 'object_detection/builders/model_builder_test.py': [Errno 2] No such file or directory

# %% [markdown]
# #Train Model

# %%
# !python object_detection/legacy/train.py \
--train_dir=<patht to checkpoint directory> \
--pipeline_config_path=<path to config file>

# %% [markdown]
# #Save inference graph

# %%
# !python object_detection/export_inference_graph.py \
--input_type=image_tensor \
--pipeline_config_path=<path to config file> \
--trained_checkpoint_prefix=<path to checkpoint> \
--output_directory=<path to inference graph output directory>
